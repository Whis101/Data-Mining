# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()
X = iris.data
y  = iris.target
sample_data = [[4.6, 3.01, 1.32, .25], [6.7, 3.2, 5.7, 2.4],[6.7, 3.2, 4.5,
1.4]]

# %%
# ENTROPY 
# 50% of data to train
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.5, random_state = 99)

clf = DecisionTreeClassifier(criterion = 'entropy',random_state=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
predictions = clf.predict(sample_data)
print(f"""sample:{sample_data[0]}->label:{predictions[0]}
sample:{sample_data[1]}->label:{predictions[1]}
sample:{sample_data[2]}->label:{predictions[2]}""")
# Out:
# Accuracy: 0.96
# sample:[4.6, 3.01, 1.32, 0.25]->label:0
# sample:[6.7, 3.2, 5.7, 2.4]->label:2
# sample:[6.7, 3.2, 4.5, 1.4]->label:1

# %%
# ENTROPY
# 70%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 99)

clf = DecisionTreeClassifier(criterion = 'entropy',random_state=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
predictions = clf.predict(sample_data)
print(f"""sample:{sample_data[0]}->label:{predictions[0]}
sample:{sample_data[1]}->label:{predictions[1]}
sample:{sample_data[2]}->label:{predictions[2]}""")
# Out:
# Accuracy: 0.9555555555555556
# sample:[4.6, 3.01, 1.32, 0.25]->label:0
# sample:[6.7, 3.2, 5.7, 2.4]->label:2
# sample:[6.7, 3.2, 4.5, 1.4]->label:1

# %%
# ENTROPY
# %90
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.1, random_state = 99)

clf = DecisionTreeClassifier(criterion = 'entropy',random_state=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
predictions = clf.predict(sample_data)
print(f"""sample:{sample_data[0]}->label:{predictions[0]}
sample:{sample_data[1]}->label:{predictions[1]}
sample:{sample_data[2]}->label:{predictions[2]}""")
# Out:
# Accuracy: 0.9333333333333333
# sample:[4.6, 3.01, 1.32, 0.25]->label:0
# sample:[6.7, 3.2, 5.7, 2.4]->label:2
# sample:[6.7, 3.2, 4.5, 1.4]->label:1

# %%
# GINI
# 50% of data to train
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.5, random_state = 99)

clf = DecisionTreeClassifier(criterion = 'gini',random_state=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
predictions = clf.predict(sample_data)
print(f"""sample:{sample_data[0]}->label:{predictions[0]}
sample:{sample_data[1]}->label:{predictions[1]}
sample:{sample_data[2]}->label:{predictions[2]}""")
# Out:
# Accuracy: 0.96
# sample:[4.6, 3.01, 1.32, 0.25]->label:0
# sample:[6.7, 3.2, 5.7, 2.4]->label:2
# sample:[6.7, 3.2, 4.5, 1.4]->label:1

# %%
# GINI
# 70%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 99)

clf = DecisionTreeClassifier(criterion = 'gini',random_state=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
predictions = clf.predict(sample_data)
print(f"""sample:{sample_data[0]}->label:{predictions[0]}
sample:{sample_data[1]}->label:{predictions[1]}
sample:{sample_data[2]}->label:{predictions[2]}""")
# Out:
# Accuracy: 0.9555555555555556
# sample:[4.6, 3.01, 1.32, 0.25]->label:0
# sample:[6.7, 3.2, 5.7, 2.4]->label:2
# sample:[6.7, 3.2, 4.5, 1.4]->label:1

# %%
# GINI
# %90
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.1, random_state = 99)

clf = DecisionTreeClassifier(criterion = 'gini',random_state=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
predictions = clf.predict(sample_data)
print(f"""sample:{sample_data[0]}->label:{predictions[0]}
sample:{sample_data[1]}->label:{predictions[1]}
sample:{sample_data[2]}->label:{predictions[2]}""")
# Out:
# Accuracy: 0.9333333333333333
# sample:[4.6, 3.01, 1.32, 0.25]->label:0
# sample:[6.7, 3.2, 5.7, 2.4]->label:2
# sample:[6.7, 3.2, 4.5, 1.4]->label:1
